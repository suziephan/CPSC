# %%
import requests

# %%
food =requests.get('https://streetfoodapp.com/vancouver/2019-06-07')

# %%
print(food.text[0:400])
# Out:
# <!DOCTYPE html><html lang="en">
#
#   <head>
#     <meta charset="utf-8">
#     <meta name="description" content="Vancouver, BC: Food Truck Locations for Friday, June 7, 2019" >
# <meta name="author" content="Street Food App" >
# <meta name="__date_tab_page_title:2019-06-04" content="Vancouver, BC: Food Truck Locations for Tuesday, June 4, 2019" >
# <meta name="__date_tab_page_title:2019-06-05" content="Vancou

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(food.text,'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="Vancouver, BC: Food Truck Locations for Friday, June 7, 2019" name="description"/>
#   <meta content="Street Food App" name="author"/>
#   <meta content="Vancouver, BC: Food Truck Locations for Tuesday, June 4, 2019" name="__date_tab_page_title:2019-06-04"/>
#   <meta content="Vancouver, BC: Food Truck Locations for Wednesday, June 5, 2019" name="__date_tab_page_title:2019-06-05"/>
#   <meta content="Vancouver, BC: Food Truck Locations for Thursday, June 6, 2019" name="__date_tab_page_title:2019-06-06"/>
#   <meta content="Vancouver, BC: Food Truck Locations for Friday, June 7, 2019" name="__date_tab_page_title:2019-06-07"/>
#   <meta content="Vancouver, BC: Food Truck Locations for Saturday, June 8, 2019" name="__date_tab_page_title:2019-06-08"/>
#   <meta content="Vancouver, BC: Food Truck Locations for Sunday, June 9, 2019" name="__date_tab_page_title:2019-06-09"/>
# ...

# %%
soup1=soup.find_all('li',attrs={"class": "list-inline-item mr-0"})

# %%
soup1
# Out:
# [<li class="list-inline-item mr-0"><a href="/vancouver/aloha-bowls">Aloha Bowls</a>,</li>,
#  <li class="list-inline-item mr-0"><a href="/vancouver/arturos-to-go">arturosmexico2go</a>,</li>,
#  <li class="list-inline-item mr-0"><a href="/vancouver/aussie-pie-guy">Aussie Pie Guy</a>,</li>,
#  <li class="list-inline-item mr-0"><a href="/vancouver/bandidas">Bandidas Food Truck</a>,</li>,
#  <li class="list-inline-item mr-0"><a href="/vancouver/bc-taco">BC TACO</a>,</li>,
#  <li class="list-inline-item mr-0"><a href="/vancouver/bc-taco-2">BC TACO 2.0</a>,</li>,
#  <li class="list-inline-item mr-0"><a href="/vancouver/bean-buggy">The Bean Buggy</a>,</li>,
#  <li class="list-inline-item mr-0"><a href="/vancouver/beljam-waffles">Beljam's Waffles</a>,</li>,
#  <li class="list-inline-item mr-0"><a href="/vancouver/bettys-greek-honey-ballz">Betty's Greek Honey Ballz</a>,</li>,
#  <li class="list-inline-item mr-0"><a href="/vancouver/big-reds-poutine">Big Red's Poutine</a>,</li>,
# ...

# %%
soup2=soup1[0]
soup2
# Out:
# <li class="list-inline-item mr-0"><a href="/vancouver/aloha-bowls">Aloha Bowls</a>,</li>

# %%
soup2.find('a').contents
# Out:
# ['Aloha Bowls']

# %%
soup2.find('a').text
# Out:
# 'Aloha Bowls'

# %%
type(soup1)
# Out:
# bs4.element.ResultSet

# %%
name=[]
for item in soup1:
    name = item.find('a').text
    print(name)
# Out:
# Aloha Bowls
# arturosmexico2go
# Aussie Pie Guy
# Bandidas Food Truck
# BC TACO
# BC TACO 2.0
# The Bean Buggy
# Beljam's Waffles
# Betty's Greek Honey Ballz
# Big Red's Poutine
# Big Red's Poutine XXL
# Stir it Up VanCity
# Bobbie's
# Bobbie's Bites
# Boca'o Spanish Tapas
# Bombay Syndicate
# Brazilian Roots Truck
# Bread and Cheese
# Brewnetti - Cafe on Wheels
# Cannoli King Vancouver
# Cazba Express
# Cheeses Crust
# Cheezee Does It
# Chickpea Truck
# Chili Tank
# Chouchou Crêpes
# Cloud Nine Cotton Candy
# Coffee Bike Vancouver
# Come Arepa
# Crab Park Chowdery
# Curb Your Appetite
# Dee's Donuts
# Disco Cheetah Korean Grill
# Dog Meister
# Dogs N Roses
# Dutchlicious
# EAT Chicken Wraps
# El Cartel Food Truck
# El Coroto Kitchen
# Eli's Serious Sausage
# Fat Duck Mobile Eatery
# Feastro The Rolling Bistro
# Feastro The Rolling Bistro 2
# Flying Fish N Chipper
# Fratelli On Wheels
# Frying Pan
# Go Curry Go
# Green Coast Cafe
# GYPSYtrunk Food Cart
# Henry's Hip Eats
# ...

# %%
soup2
# Out:
# <li class="list-inline-item mr-0"><a href="/vancouver/aloha-bowls">Aloha Bowls</a>,</li>

# %%
type(soup2)
# Out:
# bs4.element.Tag

# %%
"https://streetfoodapp.com"+soup2.a["href"]
# Out:
# 'https://streetfoodapp.com/vancouver/aloha-bowls'

# %%
url=[]
for link in soup1:
    url="https://streetfoodapp.com"+link.a["href"]
    print(url)
# Out:
# https://streetfoodapp.com/vancouver/aloha-bowls
# https://streetfoodapp.com/vancouver/arturos-to-go
# https://streetfoodapp.com/vancouver/aussie-pie-guy
# https://streetfoodapp.com/vancouver/bandidas
# https://streetfoodapp.com/vancouver/bc-taco
# https://streetfoodapp.com/vancouver/bc-taco-2
# https://streetfoodapp.com/vancouver/bean-buggy
# https://streetfoodapp.com/vancouver/beljam-waffles
# https://streetfoodapp.com/vancouver/bettys-greek-honey-ballz
# https://streetfoodapp.com/vancouver/big-reds-poutine
# https://streetfoodapp.com/vancouver/big-reds-poutine-xxl
# https://streetfoodapp.com/vancouver/bike-caffe
# https://streetfoodapp.com/vancouver/bobbies
# https://streetfoodapp.com/vancouver/bobbies-bites
# https://streetfoodapp.com/vancouver/boca-o
# https://streetfoodapp.com/vancouver/bombay-syndicate
# https://streetfoodapp.com/vancouver/brazilian-roots
# https://streetfoodapp.com/vancouver/bread-and-cheese
# https://streetfoodapp.com/vancouver/brewnetti
# ...

# %%
import pandas as pd

# %%
data=[]
for item in soup1:
    url="https://streetfoodapp.com"+item.a["href"]
    name = item.find('a').text
    data.append([name,url])

# %%
print(data)
# Out:
# [['Aloha Bowls', 'https://streetfoodapp.com/vancouver/aloha-bowls'], ['arturosmexico2go', 'https://streetfoodapp.com/vancouver/arturos-to-go'], ['Aussie Pie Guy', 'https://streetfoodapp.com/vancouver/aussie-pie-guy'], ['Bandidas Food Truck', 'https://streetfoodapp.com/vancouver/bandidas'], ['BC TACO', 'https://streetfoodapp.com/vancouver/bc-taco'], ['BC TACO 2.0', 'https://streetfoodapp.com/vancouver/bc-taco-2'], ['The Bean Buggy', 'https://streetfoodapp.com/vancouver/bean-buggy'], ["Beljam's Waffles", 'https://streetfoodapp.com/vancouver/beljam-waffles'], ["Betty's Greek Honey Ballz", 'https://streetfoodapp.com/vancouver/bettys-greek-honey-ballz'], ["Big Red's Poutine", 'https://streetfoodapp.com/vancouver/big-reds-poutine'], ["Big Red's Poutine XXL", 'https://streetfoodapp.com/vancouver/big-reds-poutine-xxl'], ['Stir it Up VanCity', 'https://streetfoodapp.com/vancouver/bike-caffe'], ["Bobbie's", 'https://streetfoodapp.com/vancouver/bobbies'], ["Bobbie's Bites", 'https://streetfooda
# ...

# %%
street_food =pd.DataFrame(data,columns=["name","url"])
street_food
# Out:
#                                   name  \
# 0                          Aloha Bowls
# 1                     arturosmexico2go
# 2                       Aussie Pie Guy
# 3                  Bandidas Food Truck
# 4                              BC TACO
# 5                          BC TACO 2.0
# 6                       The Bean Buggy
# 7                     Beljam's Waffles
# 8            Betty's Greek Honey Ballz
# 9                    Big Red's Poutine
# 10               Big Red's Poutine XXL
# 11                  Stir it Up VanCity
# 12                            Bobbie's
# 13                      Bobbie's Bites
# 14                Boca'o Spanish Tapas
# 15                    Bombay Syndicate
# 16               Brazilian Roots Truck
# 17                    Bread and Cheese
# 18          Brewnetti - Cafe on Wheels
# 19              Cannoli King Vancouver
# 20                       Cazba Express
# 21                       Cheeses Crust
# 22                     Cheezee Does It
# ...
